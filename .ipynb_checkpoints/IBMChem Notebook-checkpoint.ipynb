# %% [markdown]
# <h1>Predicting Pharmaceutical Sales</h1>

# %% [markdown]
# # Business Understanding
# #### Operating Environment
# <p>The client is a retailer operating in the pharmaceuitcal industry with a number of stores across the East Cost of Australia. They have recently found increased demand for Vitamin and health products and are seeking to better understand what drives demans so they can take full advantage of the increased market capacity. </p>
#
# #### Business Goal
# <p>As of late, the client has found that they are struggling with stockouts. This occurs when there is no stock left of a particular item which is in demand. This has led to lost revenue and missed opportunities for sales. As a result the client wishes to minimize the occurence of stockouts. A large part of minimizing stockouts is predicting sales accurate so that stock levels can be predictive. The formula for closing inventory is given by: </p>
#     <blockquote>Closing Inventory = Opening Inventory - Today's Sales + Returns + Stock Deliveries</blockquote>
#
# #### Strategy
# <p>For stage one of the project, the team has decided to explore the idea of better predicting sales. Future enhancements could involve predicting product returns and using prescriptive analytics to drive stock purchases/deliveries. </p>
#
# #### Source Data
# <p>The dataset has been extract from a Planning Analytics sales cube. The finance and operations team typically use PA to plan for their stock levels and sales forecasts hence this has been chosen as the appropriate repository. </p>

# %%
import warnings

# %% [markdown]
# # Import Data

# %%
import pandas as pd

# %%
from pandas import DataFrame

# %% [markdown]
# ### Setup IBM Cloud Client
# Replace the IBM API KEY ID with yours obtained from IBM COS. This can be obtained by selecting the Find and Add Data tab in the top right, selecting a data source and choosing add credentials.

# %%
import types
from botocore.client import Config
import ibm_boto3

client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='<YOUR IBM COS API KEY>',
    ibm_auth_endpoint="https://iam.ng.bluemix.net/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

# %% [markdown]
# ### Datasets Available
# We have a number of datasets to work with in this scenario. A data dictionary is provided below:
# 1. IBMChem_Products.csv
# 2. IBMChem_Sales.csv
# 3. IBMChem_stores.csv
# 4. Weather.csv
#
# These are currently stores in IBM Cloud Object Storage. They can be retrieved easily using the COS client. To upload the datasets, select

# %% [markdown]
# ### Import Sales Data from IBM COS

# %%
body = client.get_object(Bucket='<YOUR BUCKET>',Key='IBMChem_Sales.csv')['Body']
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df = pd.read_csv(body)
df.head()
# Out:
#    Time Date  Product          Store  Value
# 0    1012018  2511675  QLD_CW_ST0005  562.1
# 1    1012018  2511675  QLD_CW_ST0203  715.4
# 2    1012018  2511675  QLD_CW_ST0113  459.9
# 3    1012018  2511675  QLD_CW_ST0098  408.8
# 4    1012018  2511675  QLD_CW_ST0132  357.7

# %%
# Convert numerical product id to categorical variable
df['Product'] = df['Product'].astype(str)

# %%
df.dtypes
# Out:
# Time Date      int64
# Product       object
# Store         object
# Value        float64
# dtype: object

# %% [markdown]
# ### Import Product Metadata from IBM COS

# %%
body = client.get_object(Bucket='<YOUR BUCKET>',Key='IBMChem_Products.csv')['Body']
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

products = pd.read_csv(body)
products.head()
# Out:
#    ProductID Good Weather Impact  Brand Affinity  Product Size       Brand  \
# 0    2477202            Negative              10           200     Cenovis
# 1    2482445            Positive              10           200     Cenovis
# 2    2485787            Negative               2           168  Blackmores
# 3    2490626            Negative               9            62  Blackmores
# 4    2490701            Positive               9            62  Blackmores
#
#    Category                SubCategory                             Description
# 0  Vitamins             Multi Vitamins     Multivitamin & Minerals 200 Tablets
# 1  Vitamins  Bones, Joints and Muscles  Mega Calcium +D 200 Tablets Value Pack
# 2  Vitamins     Cold, Flu and Immunity                    Bio Zinc 168 Tablets
# 3  Vitamins     Cold, Flu and Immunity       Bio C 1000mg 62 Tablets Vitamin C
# 4  Vitamins                     Energy   Executive B Stress Formula 62 Tablets

# %%
products['ProductID'] = products['ProductID'].astype(str)

# %%
products.dtypes
# Out:
# ProductID              object
# Good Weather Impact    object
# Brand Affinity          int64
# Product Size            int64
# Brand                  object
# Category               object
# SubCategory            object
# Description            object
# dtype: object

# %% [markdown]
# ### Import Store Metadata from IBM COS

# %%
body = client.get_object(Bucket='<YOUR BUCKET>',Key='IBMChem_stores.csv')['Body']
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

stores = pd.read_csv(body)

# %%
stores.columns = ['Store', 'Store Description', 'Address', 'Suburb', 'State', 'Phone', 'Lat', 'Long', 'RegionAffluence']

# %%
stores['State'] = stores['Store'].apply(lambda x: x[:3].strip())

# %%
stores.head()
# Out:
#            Store                            Store Description  \
# 0  QLD_CW_ST0005   Chemist Warehouse Adelaide Street Brisbane
# 1  QLD_CW_ST0203           Chemist Warehouse Fortitude Valley
# 2  QLD_CW_ST0113                   Chemist Warehouse Annerley
# 3  QLD_CW_ST0098              Chemist Warehouse Indooroopilly
# 4  QLD_CW_ST0132                 Chemist Warehouse Mt Gravatt
#
#                                              Address             Suburb State  \
# 0                                SH6 215 Adelaide St           Brisbane   QLD
# 1            Sh 43 to 46 Emporium Centre 1000 Ann St   Fortitude Valley   QLD
# 2                                   493 Ipswich Road           Annerley   QLD
# 3           Shop 1 34 Coonan St Indooroopilly Centro      Indooroopilly   QLD
# 4   Shop 10 Mt Gravatt Homemaker Centre 1230 Loga...      Mount Gravatt   QLD
#
#            Phone       Lat       Long  RegionAffluence
# 0   07 3221 3905 -27.46739  153.02692              1.1
# 1   07 3252 2645 -27.45350  153.03949              1.4
# 2   07 3848 1046 -27.51223  153.03114              0.9
# 3   07 3720 0511 -27.49723  152.97599              0.8
# 4   07 3349 3430 -27.53004  153.07291              0.7

# %% [markdown]
# ### Import Weather Data from IBM COS

# %%
body = client.get_object(Bucket='<YOUR BUCKET>',Key='Weather.csv')['Body']
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

weather = pd.read_csv(body)
weather.head()
# Out:
#       Date State  Temperature  Precipitation
# 0  1012018   NSW           23           0.00
# 1  2012018   NSW           24           3.05
# 2  3012018   NSW           21           0.51
# 3  4012018   NSW           21           0.00
# 4  5012018   NSW           22           0.00

# %% [markdown]
# # Data Understanding
# <p>The CRISP-DM methodology has been followed to ensure industry agreed best practices are used. Following obtaining an understanding of the busienss the next focus is to obtain an understanding of the data available. This includes obtaining an understanding of data structures, types, data quality and relationships.</p>

# %% [markdown]
# ## Basic Data Checking

# %% [markdown]
# ### Check data format
# - Data is sales data by product, account, store and day
# - Date format is ddmmyyy

# %%
# Review data format 
df.head()
# Out:
#    Time Date  Product          Store  Value
# 0    1012018  2511675  QLD_CW_ST0005  562.1
# 1    1012018  2511675  QLD_CW_ST0203  715.4
# 2    1012018  2511675  QLD_CW_ST0113  459.9
# 3    1012018  2511675  QLD_CW_ST0098  408.8
# 4    1012018  2511675  QLD_CW_ST0132  357.7

# %% [markdown]
# ### Review summary statistics
# - 18 Stores
# - 69 Products within the dataset

# %%
df.describe()
# Out:
#           Time Date          Value
# count  4.533300e+05  453330.000000
# mean   1.578783e+07     357.212419
# std    8.796734e+06     258.276412
# min    1.012018e+06       6.982500
# 25%    8.082018e+06     135.000000
# 50%    1.603202e+07     301.945644
# 75%    2.310202e+07     536.431896
# max    3.112202e+07    1386.000000

# %%
df.describe(include=['object'])
# Out:
#         Product          Store
# count    453330         453330
# unique       69             18
# top     2673114  QLD_CW_ST0005
# freq       6570          25185

# %% [markdown]
# ### Review Data Types
# - Time Date should be a DateTime Object
# - Account should be categorical
# - Product should be categorical

# %%
df.dtypes
# Out:
# Time Date      int64
# Product       object
# Store         object
# Value        float64
# dtype: object

# %% [markdown]
# ### Check for missing values
# - No missing values noted

# %%
df.isnull().sum()
# Out:
# Time Date    0
# Product      0
# Store        0
# Value        0
# dtype: int64

# %% [markdown]
# ### Merge Dataframes

# %%
abt = pd.merge(df, stores, how='left')
abt = pd.merge(abt, products, left_on='Product', right_on='ProductID', how='left')
abt = pd.merge(abt, weather, left_on=['State', 'Time Date'], right_on=['State','Date'], how='left')
abt.drop('Date',axis = 1, inplace=True)
abt['Time Date'] = abt['Time Date'].apply(lambda x: '0' + str(x) if len(str(x)) < 8 else str(x))
abt['Time Date'] = pd.to_datetime(abt['Time Date'], format='%d%m%Y')

# %%
abt.head()
# Out:
#    Time Date  Product          Store  Value  \
# 0 2018-01-01  2511675  QLD_CW_ST0005  562.1
# 1 2018-01-01  2511675  QLD_CW_ST0203  715.4
# 2 2018-01-01  2511675  QLD_CW_ST0113  459.9
# 3 2018-01-01  2511675  QLD_CW_ST0098  408.8
# 4 2018-01-01  2511675  QLD_CW_ST0132  357.7
#
#                              Store Description  \
# 0   Chemist Warehouse Adelaide Street Brisbane
# 1           Chemist Warehouse Fortitude Valley
# 2                   Chemist Warehouse Annerley
# 3              Chemist Warehouse Indooroopilly
# 4                 Chemist Warehouse Mt Gravatt
#
#                                              Address             Suburb State  \
# 0                                SH6 215 Adelaide St           Brisbane   QLD
# 1            Sh 43 to 46 Emporium Centre 1000 Ann St   Fortitude Valley   QLD
# 2                                   493 Ipswich Road           Annerley   QLD
# 3           Shop 1 34 Coonan St Indooroopilly Centro      Indooroopilly   QLD
# 4   Shop 10 Mt Gravatt Homemaker Centre 1230 Loga...      Mount Gravatt   QLD
#
#            Phone       Lat  ...  ProductID  Good Weather Impact  \
# 0   07 3221 3905 -27.46739  ...    2511675             Negative
# 1   07 3252 2645 -27.45350  ...    2511675             Negative
# 2   07 3848 1046 -27.51223  ...    2511675             Negative
# 3   07 3720 0511 -27.49723  ...    2511675             Negative
# 4   07 3349 3430 -27.53004  ...    2511675             Negative
#
#   Brand Affinity Product Size    Brand  Category             SubCategory  \
# 0             10           60  Cenovis  Vitamins  Cold, Flu and Immunity
# 1             10           60  Cenovis  Vitamins  Cold, Flu and Immunity
# 2             10           60  Cenovis  Vitamins  Cold, Flu and Immunity
# 3             10           60  Cenovis  Vitamins  Cold, Flu and Immunity
# 4             10           60  Cenovis  Vitamins  Cold, Flu and Immunity
#
#   Description Temperature Precipitation
# 0      Mega C          27           0.0
# 1      Mega C          27           0.0
# 2      Mega C          27           0.0
# 3      Mega C          27           0.0
# 4      Mega C          27           0.0
#
# [5 rows x 22 columns]

# %%
abt.to_csv('IBMChem Analytical Base Table.csv')

# %%
# Backup Analytical Base Table 
client.upload_file('IBMChem Analytical Base Table.csv', '<YOUR BUCKET>', 'IBMChem Analytical Base Table.csv')

# %% [markdown]
# # Visualization

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Analysing Sales by Subcategory
# - Good weather impact flag highlights that sales are somewhat influenced by the time of the year.
# - Cold and Flu, MultiVitamins and Omega 3 appear to sell better in the winter/colder months.
# - Beauty, Joint and Energy supplements to sell better in the hotter/summer months.
#
# These insights appear consistent with the businesses known product sales trends.

# %% [markdown]
# ### Plot By Subcategory

# %%
subcat = abt.groupby(['SubCategory','Time Date']).sum()

# %%
subcat.reset_index(inplace=True)

# %%
warnings.filterwarnings("ignore")
plt.figure(figsize=(30,10))
ax = sns.lineplot(x=subcat['Time Date'], y=subcat['Value'],
             hue=subcat['SubCategory'], markers=True,
             data=subcat, palette="tab10", linewidth=2.5)
ax.set(xlabel='Date', ylabel='Sales')
plt.show()

# %% [markdown]
# ### Plot Positive Weather Impact

# %%
warnings.filterwarnings("ignore")
subcat = abt[abt['Good Weather Impact']=='Positive'].groupby(['SubCategory','Time Date']).sum()
subcat.reset_index(inplace=True)
plt.figure(figsize=(30,10))
ax = sns.lineplot(x=subcat['Time Date'], y=subcat['Value'],
             hue=subcat['SubCategory'], markers=True,
             data=subcat, palette="tab10", linewidth=2.5)
ax.set(xlabel='Date', ylabel='Sales')
plt.show()

# %% [markdown]
# ### Plot Negative Sales

# %%
warnings.filterwarnings("ignore")
subcat = abt[abt['Good Weather Impact']=='Negative'].groupby(['SubCategory','Time Date']).sum()
subcat.reset_index(inplace=True)
plt.figure(figsize=(30,10))
ax = sns.lineplot(x=subcat['Time Date'], y=subcat['Value'],
             hue=subcat['SubCategory'], markers=True,
             data=subcat, palette="tab10", linewidth=2.5)
ax.set(xlabel='Date', ylabel='Sales')
plt.show()

# %% [markdown]
# ## Analysing Correlation

# %% [markdown]
# ### Overall Correlation
# - Sales values appear to be strongly positively correlated with Brand Affinity,  Region Affluence.
# - There is also some weak positive correlation between sales and temperature.

# %%
abt.drop(['Lat','Long'],axis=1).corr()
# Out:
#                     Value  RegionAffluence  Brand Affinity  Product Size  \
# Value            1.000000     3.351128e-01    6.919460e-01 -2.825252e-02
# RegionAffluence  0.335113     1.000000e+00   -3.511636e-18  2.766275e-21
# Brand Affinity   0.691946    -3.511636e-18    1.000000e+00 -1.627142e-03
# Product Size    -0.028253     2.766275e-21   -1.627142e-03  1.000000e+00
# Temperature      0.144874    -1.852618e-02    1.463867e-16  1.486617e-17
# Precipitation   -0.052431    -2.689019e-03   -4.233716e-16  6.761438e-17
#
#                   Temperature  Precipitation
# Value            1.448744e-01  -5.243107e-02
# RegionAffluence -1.852618e-02  -2.689019e-03
# Brand Affinity   1.463867e-16  -4.233716e-16
# Product Size     1.486617e-17   6.761438e-17
# Temperature      1.000000e+00   6.909131e-02
# Precipitation    6.909131e-02   1.000000e+00

# %%
plt.figure(figsize=(8,8))
sns.heatmap(abt.drop(['Lat','Long'],axis=1).corr())
plt.show()

# %% [markdown]
# ### Analysing Good Weather Impact Correlation - Positive Flags
# - After filtering out sales for only those products with a Positive Good Weather Impact flat we can see there there is signifcantly stronger correlation with temperature.
# - This is consistent with the plots above where weather would be hotter during the summer months in Australia

# %%
abt[abt['Good Weather Impact']=='Positive'].drop(['Lat','Long'],axis=1).corr()
# Out:
#                     Value  RegionAffluence  Brand Affinity  Product Size  \
# Value            1.000000     3.214016e-01    5.814742e-01  1.012682e-01
# RegionAffluence  0.321402     1.000000e+00    9.439044e-18  8.462327e-21
# Brand Affinity   0.581474     9.439044e-18    1.000000e+00  1.741577e-01
# Product Size     0.101268     8.462327e-21    1.741577e-01  1.000000e+00
# Temperature      0.600242    -1.852618e-02   -1.168050e-16 -2.536090e-17
# Precipitation   -0.022524    -2.689019e-03    9.324487e-17 -5.014840e-17
#
#                   Temperature  Precipitation
# Value            6.002420e-01  -2.252428e-02
# RegionAffluence -1.852618e-02  -2.689019e-03
# Brand Affinity  -1.168050e-16   9.324487e-17
# Product Size    -2.536090e-17  -5.014840e-17
# Temperature      1.000000e+00   6.909131e-02
# Precipitation    6.909131e-02   1.000000e+00

# %%
plt.figure(figsize=(8,8))
sns.heatmap(abt[abt['Good Weather Impact']=='Positive'].drop(['Lat','Long'],axis=1).corr())
plt.show()

# %% [markdown]
# ### Analysing Good Weather Impact Correlation - Negative Flags
# - After filtering out sales for only those products with a Negative Good Weather Impact flat we can see there there is stronger negative correlation with temperature.
# - This is also consistent with the plots above where weather would be colder during the winter months in Australia

# %%
abt[abt['Good Weather Impact']=='Negative'].drop(['Lat','Long'],axis=1).corr()
# Out:
#                     Value  RegionAffluence  Brand Affinity  Product Size  \
# Value            1.000000     3.674126e-01    8.560670e-01 -1.130784e-01
# RegionAffluence  0.367413     1.000000e+00    3.335711e-18  3.074985e-18
# Brand Affinity   0.856067     3.335711e-18    1.000000e+00 -1.320906e-01
# Product Size    -0.113078     3.074985e-18   -1.320906e-01  1.000000e+00
# Temperature     -0.225069    -1.852618e-02    8.943339e-17  5.731086e-17
# Precipitation   -0.080589    -2.689019e-03    1.005125e-16 -4.386658e-17
#
#                   Temperature  Precipitation
# Value           -2.250688e-01  -8.058885e-02
# RegionAffluence -1.852618e-02  -2.689019e-03
# Brand Affinity   8.943339e-17   1.005125e-16
# Product Size     5.731086e-17  -4.386658e-17
# Temperature      1.000000e+00   6.909131e-02
# Precipitation    6.909131e-02   1.000000e+00

# %%
plt.figure(figsize=(8,8))
sns.heatmap(abt[abt['Good Weather Impact']=='Positive'].drop(['Lat','Long'],axis=1).corr())
plt.show()

# %% [markdown]
# # Data Preparation
# <p>During the data understanding process there were a few key points which were uncovered. These were:</p>
# <ul>
#     <li>There are a number of features which are non-unique</li>
#     <li>The Time Date column indicates that this data is time series based</li>
#     <li>There are no missing values</li>
#     <li>The account and product features need to be converted to categorical features</li>
# </ul>

# %% [markdown]
# ### Remove Unneeded Features

# %%
abt.describe(include='object')
# Out:
#         Product          Store             Store Description  \
# count    453330         453330                        453330
# unique       69             18                            18
# top     2673114  QLD_CW_ST0005   Chemist Warehouse Bankstown
# freq       6570          25185                         25185
#
#                    Address     Suburb   State          Phone ProductID  \
# count               453330     453330  453330         453330    453330
# unique                  18         18       3             18        69
# top      105 Haldon Street   Hawthorn     NSW   07 3848 1046   2673114
# freq                 25185      25185  176295          25185      6570
#
#        Good Weather Impact       Brand  Category             SubCategory  \
# count               453330      453330    453330                  453330
# unique                   2          16         1                       7
# top               Positive  Blackmores  Vitamins  Cold, Flu and Immunity
# freq                229950      111690    453330                  111690
#
#                        Description
# count                       453330
# unique                          69
# top     Echinacea 5000 60 Capsules
# freq                          6570

# %%
abt.drop(['Store Description', 'Address', 'Suburb', 'Phone', 'ProductID', 'Category', 'Description'], axis=1, inplace=True)

# %%
abt.head()
# Out:
#    Time Date  Product          Store  Value State       Lat       Long  \
# 0 2018-01-01  2511675  QLD_CW_ST0005  562.1   QLD -27.46739  153.02692
# 1 2018-01-01  2511675  QLD_CW_ST0203  715.4   QLD -27.45350  153.03949
# 2 2018-01-01  2511675  QLD_CW_ST0113  459.9   QLD -27.51223  153.03114
# 3 2018-01-01  2511675  QLD_CW_ST0098  408.8   QLD -27.49723  152.97599
# 4 2018-01-01  2511675  QLD_CW_ST0132  357.7   QLD -27.53004  153.07291
#
#    RegionAffluence Good Weather Impact  Brand Affinity  Product Size    Brand  \
# 0              1.1            Negative              10            60  Cenovis
# 1              1.4            Negative              10            60  Cenovis
# 2              0.9            Negative              10            60  Cenovis
# 3              0.8            Negative              10            60  Cenovis
# 4              0.7            Negative              10            60  Cenovis
#
#               SubCategory  Temperature  Precipitation
# 0  Cold, Flu and Immunity           27            0.0
# 1  Cold, Flu and Immunity           27            0.0
# 2  Cold, Flu and Immunity           27            0.0
# 3  Cold, Flu and Immunity           27            0.0
# 4  Cold, Flu and Immunity           27            0.0

# %%
abt.drop(['Lat', 'Long'], axis=1, inplace=True)

# %%
abt.head()
# Out:
#    Time Date  Product          Store  Value State  RegionAffluence  \
# 0 2018-01-01  2511675  QLD_CW_ST0005  562.1   QLD              1.1
# 1 2018-01-01  2511675  QLD_CW_ST0203  715.4   QLD              1.4
# 2 2018-01-01  2511675  QLD_CW_ST0113  459.9   QLD              0.9
# 3 2018-01-01  2511675  QLD_CW_ST0098  408.8   QLD              0.8
# 4 2018-01-01  2511675  QLD_CW_ST0132  357.7   QLD              0.7
#
#   Good Weather Impact  Brand Affinity  Product Size    Brand  \
# 0            Negative              10            60  Cenovis
# 1            Negative              10            60  Cenovis
# 2            Negative              10            60  Cenovis
# 3            Negative              10            60  Cenovis
# 4            Negative              10            60  Cenovis
#
#               SubCategory  Temperature  Precipitation
# 0  Cold, Flu and Immunity           27            0.0
# 1  Cold, Flu and Immunity           27            0.0
# 2  Cold, Flu and Immunity           27            0.0
# 3  Cold, Flu and Immunity           27            0.0
# 4  Cold, Flu and Immunity           27            0.0

# %% [markdown]
# ## Remove features unlikely to add value

# %%
abt.drop(['State', 'Brand', 'SubCategory'], axis=1, inplace=True)

# %%
abt.head()
# Out:
#       Time Date  Product          Store     Value  RegionAffluence  \
# 0    2018-01-01  2511675  QLD_CW_ST0005  562.1000              1.1
# 1242 2018-01-02  2511675  QLD_CW_ST0005  552.4211              1.1
# 2484 2018-01-03  2511675  QLD_CW_ST0005  569.8000              1.1
# 3726 2018-01-04  2511675  QLD_CW_ST0005  592.9000              1.1
# 4968 2018-01-05  2511675  QLD_CW_ST0005  577.5000              1.1
#
#      Good Weather Impact  Brand Affinity  Product Size  Temperature  \
# 0               Negative              10            60           27
# 1242            Negative              10            60           26
# 2484            Negative              10            60           26
# 3726            Negative              10            60           23
# 4968            Negative              10            60           25
#
#       Precipitation
# 0              0.00
# 1242           3.05
# 2484           0.00
# 3726           0.00
# 4968           0.00

# %% [markdown]
# ### Increase Richness of Timescale

# %% [markdown]
# This datepart function is adopted from the fastai library developed by Jeremy Howard and team.

# %%
import re
import numpy as np

def ifnone(a,b):
    "`a` if `a` is not None, otherwise `b`."
    return b if a is None else a

def make_date(df, date_field:str):
    "Make sure `df[field_name]` is of the right date type."
    field_dtype = df[date_field].dtype
    if isinstance(field_dtype, pd.core.dtypes.dtypes.DatetimeTZDtype):
        field_dtype = np.datetime64
    if not np.issubdtype(field_dtype, np.datetime64):
        df[date_field] = pd.to_datetime(df[date_field], infer_datetime_format=True)
        
def add_datepart(df, field_name:str, prefix:str=None, drop:bool=True, time:bool=False):
    "Helper function that adds columns relevant to a date in the column `field_name` of `df`."
    "Sourced from FastAI"
    make_date(df, field_name)
    field = df[field_name]
    prefix = ifnone(prefix, re.sub('[Dd]ate$', '', field_name))
    attr = ['Year', 'Month', 'Week', 'Day', 'Dayofweek', 'Dayofyear', 'Is_month_end', 'Is_month_start', 
            'Is_quarter_end', 'Is_quarter_start', 'Is_year_end', 'Is_year_start']
    if time: attr = attr + ['Hour', 'Minute', 'Second']
    for n in attr: df[prefix + n] = getattr(field.dt, n.lower())
    df[prefix + 'Elapsed'] = field.astype(np.int64) // 10 ** 9
    if drop: df.drop(field_name, axis=1, inplace=True)
    return df

# %%
abt = add_datepart(abt, 'Time Date')

# %%
abt.head()
# Out:
#       Product          Store     Value  RegionAffluence Good Weather Impact  \
# 0     2511675  QLD_CW_ST0005  562.1000              1.1            Negative
# 1242  2511675  QLD_CW_ST0005  552.4211              1.1            Negative
# 2484  2511675  QLD_CW_ST0005  569.8000              1.1            Negative
# 3726  2511675  QLD_CW_ST0005  592.9000              1.1            Negative
# 4968  2511675  QLD_CW_ST0005  577.5000              1.1            Negative
#
#       Brand Affinity  Product Size  Temperature  Precipitation  Time Year  \
# 0                 10            60           27           0.00       2018
# 1242              10            60           26           3.05       2018
# 2484              10            60           26           0.00       2018
# 3726              10            60           23           0.00       2018
# 4968              10            60           25           0.00       2018
#
#       ...  Time Day  Time Dayofweek  Time Dayofyear  Time Is_month_end  \
# 0     ...         1               0               1              False
# 1242  ...         2               1               2              False
# 2484  ...         3               2               3              False
# 3726  ...         4               3               4              False
# 4968  ...         5               4               5              False
#
#       Time Is_month_start  Time Is_quarter_end  Time Is_quarter_start  \
# 0                    True                False                   True
# 1242                False                False                  False
# 2484                False                False                  False
# 3726                False                False                  False
# 4968                False                False                  False
#
#       Time Is_year_end  Time Is_year_start  Time Elapsed
# 0                False                True    1514764800
# 1242             False               False    1514851200
# 2484             False               False    1514937600
# 3726             False               False    1515024000
# 4968             False               False    1515110400
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Simplifying the Data Pipeline

# %%
def get_abt():
    abt = pd.merge(df, stores, how='left')
    abt = pd.merge(abt, products, left_on='Product', right_on='ProductID', how='left')
    abt = pd.merge(abt, weather, left_on=['State', 'Time Date'], right_on=['State','Date'], how='left')
    abt.drop('Date',axis = 1, inplace=True)
    abt['Time Date'] = abt['Time Date'].apply(lambda x: '0' + str(x) if len(str(x)) < 8 else str(x))
    abt['Time Date'] = pd.to_datetime(abt['Time Date'], format='%d%m%Y')
    abt.drop(['Lat','Long'],axis=1).corr()
    abt.drop(['Store Description', 'Address', 'Suburb', 'Phone', 'ProductID', 'Category', 'Description'], axis=1, inplace=True)
    abt.drop(['State', 'Brand', 'SubCategory'], axis=1, inplace=True)
    abt.drop(['Lat', 'Long'], axis=1, inplace=True) 
    abt = add_datepart(abt, 'Time Date', drop=False)
    abt.sort_values(by=['Time Date', 'Product', 'Store'])
    return abt

# %%
abt = get_abt()

# %%
abt.head()
# Out:
#    Time Date  Product          Store  Value  RegionAffluence  \
# 0 2018-01-01  2511675  QLD_CW_ST0005  562.1              1.1
# 1 2018-01-01  2511675  QLD_CW_ST0203  715.4              1.4
# 2 2018-01-01  2511675  QLD_CW_ST0113  459.9              0.9
# 3 2018-01-01  2511675  QLD_CW_ST0098  408.8              0.8
# 4 2018-01-01  2511675  QLD_CW_ST0132  357.7              0.7
#
#   Good Weather Impact  Brand Affinity  Product Size  Temperature  \
# 0            Negative              10            60           27
# 1            Negative              10            60           27
# 2            Negative              10            60           27
# 3            Negative              10            60           27
# 4            Negative              10            60           27
#
#    Precipitation  ...  Time Day  Time Dayofweek  Time Dayofyear  \
# 0            0.0  ...         1               0               1
# 1            0.0  ...         1               0               1
# 2            0.0  ...         1               0               1
# 3            0.0  ...         1               0               1
# 4            0.0  ...         1               0               1
#
#    Time Is_month_end  Time Is_month_start  Time Is_quarter_end  \
# 0              False                 True                False
# 1              False                 True                False
# 2              False                 True                False
# 3              False                 True                False
# 4              False                 True                False
#
#    Time Is_quarter_start  Time Is_year_end  Time Is_year_start  Time Elapsed
# 0                   True             False                True    1514764800
# 1                   True             False                True    1514764800
# 2                   True             False                True    1514764800
# 3                   True             False                True    1514764800
# 4                   True             False                True    1514764800
#
# [5 rows x 23 columns]

# %% [markdown]
# # Modelling

# %%
modabt = pd.get_dummies(abt.drop(['Time Date', 'Product', 'Store'], axis=1))

# %%
y = modabt['Value']
X = modabt.drop('Value', axis=1)

# %% [markdown]
# ### Split Data into Train and Test

# %%
from sklearn.model_selection import train_test_split

# %%
np.random.seed(42)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.90, random_state=42)

# %%
X_train.head(2)
# Out:
#         RegionAffluence  Brand Affinity  Product Size  Temperature  \
# 19531               1.4               2            10           22
# 405780              0.7              10            40           19
#
#         Precipitation  Time Year  Time Month  Time Week  Time Day  \
# 19531             0.0       2018           1          3        16
# 405780            0.0       2018          11         47        23
#
#         Time Dayofweek  Time Dayofyear  Time Is_month_end  \
# 19531                1              16              False
# 405780               4             327              False
#
#         Time Is_month_start  Time Is_quarter_end  Time Is_quarter_start  \
# 19531                 False                False                  False
# 405780                False                False                  False
#
#         Time Is_year_end  Time Is_year_start  Time Elapsed  \
# 19531              False               False    1516060800
# 405780             False               False    1542931200
#
#         Good Weather Impact_Negative  Good Weather Impact_Positive
# 19531                              1                             0
# 405780                             1                             0

# %%
X_test.head(2)
# Out:
#         RegionAffluence  Brand Affinity  Product Size  Temperature  \
# 27520               0.7              10           400           21
# 349571              0.9              10            60           19
#
#         Precipitation  Time Year  Time Month  Time Week  Time Day  \
# 27520             0.0       2018           1          4        23
# 349571            0.0       2018          10         41         9
#
#         Time Dayofweek  Time Dayofyear  Time Is_month_end  \
# 27520                1              23              False
# 349571               1             282              False
#
#         Time Is_month_start  Time Is_quarter_end  Time Is_quarter_start  \
# 27520                 False                False                  False
# 349571                False                False                  False
#
#         Time Is_year_end  Time Is_year_start  Time Elapsed  \
# 27520              False               False    1516665600
# 349571             False               False    1539043200
#
#         Good Weather Impact_Negative  Good Weather Impact_Positive
# 27520                              0                             1
# 349571                             0                             1

# %%
y_train.head(2)
# Out:
# 19531     152.88
# 405780    453.60
# Name: Value, dtype: float64

# %%
y_test.head(2)
# Out:
# 27520     441.0
# 349571    399.0
# Name: Value, dtype: float64

# %% [markdown]
# ### Import Models

# %%
from sklearn.linear_model import Ridge, Lasso, ElasticNet
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.neural_network import MLPRegressor

# %% [markdown]
# ### Import Processing and Model Selection Tools

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
random_state = 42

# %%
# GB and NN algorithms take a significant amount of time to train
# Uncomment the lines if you want these to train
pipelines = {
    #'ridge': make_pipeline(StandardScaler(), Ridge(random_state)),
    #'lasso': make_pipeline(StandardScaler(), Lasso(random_state)),
    #'enet': make_pipeline(StandardScaler(), ElasticNet(random_state)),
    'rf': make_pipeline(StandardScaler(), RandomForestRegressor(random_state)),
    #'gb': make_pipeline(StandardScaler(), GradientBoostingRegressor(random_state)),
    #'nn': make_pipeline(StandardScaler(), MLPRegressor(random_state))
}

# %%
hyper ={
    'ridge': {'ridge__alpha':[0.01, 0.1, 0.5, 1.0]},
    'lasso': {'lasso__alpha':[0.01, 0.1, 0.5, 1.0]},
    'enet': {'elasticnet__alpha':[0.01, 0.1, 0.5, 1.0]},
    'rf': {'randomforestregressor__min_samples_split':[2,4,6]},
    'gb': {'gradientboostingregressor__alpha':[0.001, 0.005, 0.01]},
    'nn': {'mlpregressor__max_iter':[100,200], 'mlpregressor__solver':['adam', 'sgd'], 'mlpregressor__learning_rate':['invscaling', 'constant','adaptive']},
}

# %%
from sklearn.pipeline import Pipeline

# %%
X_train.shape
# Out:
# (45333, 20)

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    print(algo)
    model = GridSearchCV(pipeline, hyper[algo], n_jobs=-1, cv=10)
    model.fit(X_train, y_train)
    fit_models[algo] = model.fit(X_train, y_train)
    print('Fit '+ algo)
# Out:
# rf
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  42 out of  42 | elapsed:    9.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fit rf
# [Parallel(n_jobs=1)]: Done  42 out of  42 | elapsed:    9.1s finished

# %%
# Export models after training to save progress
import pickle
with open('fitmodels_generated.pkl', 'wb') as f:
    pickle.dump(fit_models, f)

# %%
model = fit_models['rf']

# %% [markdown]
# # Model Evaluation
# Training against the RF algorithm yielded the following results:
# - Test MSE: 97.19
# - R2: .9985
# - MAE: 3.308

# %% [markdown]
# ### Analyse Results

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
for algo, model in fit_models.items():
    y_hat = model.predict(X_test)
    mse = mean_squared_error(y_test, y_hat)
    mae = mean_absolute_error(y_test, y_hat)
    r2 = r2_score(y_test, y_hat)
    print('{}: Test MSE is {}, Test R2 is {}, Test MAE is {}'.format(algo, mse, r2, mae))
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# rf: Test MSE is 97.19459076737948, Test R2 is 0.9985441482601678, Test MAE is 3.307700285116017
# [Parallel(n_jobs=1)]: Done  42 out of  42 | elapsed:    5.1s finished

# %% [markdown]
# ### Visualize Results

# %%
model = fit_models['rf'].best_estimator_

# %%
y_hat = model.predict(X)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  42 out of  42 | elapsed:    2.9s finished

# %%
abt['yhat'] = y_hat
abt['y_test'] = y

# %%
vizdata = abt[['Time Date', 'yhat', 'y_test']].groupby('Time Date').sum()

# %%
vizdata.reset_index().plot(x='Time Date', y=['yhat', 'y_test'], figsize=(10,5), grid=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-193-61d96f4b9873> in <module>
# ----> 1 vizdata.reset_index().plot(x='Time Date', y=['yhat', 'y_test'], figsize=(10,5), grid=True)
#       2 plt.show()
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2937                           fontsize=fontsize, colormap=colormap, table=table,
#    2938                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2939                           sort_columns=sort_columns, **kwds)
#    2940     __call__.__doc__ = plot_frame.__doc__
#    2941
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/plotting/_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1968                  yerr=yerr, xerr=xerr,
#    1969                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1970                  **kwds)
#    1971
#    1972
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/plotting/_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1780
#    1781                 # don't overwrite
# -> 1782                 data = data[y].copy()
#    1783
#    1784                 if isinstance(data, ABCSeries):
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# -> 1354                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1355         else:
#    1356             try:
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1159         self._validate_read_indexer(keyarr, indexer,
#    1160                                     o._get_axis_number(axis),
# -> 1161                                     raise_missing=raise_missing)
#    1162         return keyarr, indexer
#    1163
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1244                 raise KeyError(
#    1245                     u"None of [{key}] are in the [{axis}]".format(
# -> 1246                         key=key, axis=self.obj._get_axis_name(axis)))
#    1247
#    1248             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['yhat', 'y_test'], dtype='object')] are in the [columns]"

# %%
abt['Diff'] = abt['yhat'] - abt['y_test']

# %%
vizdata = abt[['Time Date', 'Store', 'Diff']].groupby(['Time Date', 'Store']).sum().reset_index()

# %% [markdown]
# ### Visualise Errors

# %%
warnings.filterwarnings("ignore")
plt.figure(figsize=(30,10))
ax = sns.lineplot(x=vizdata['Time Date'], y=vizdata['Diff'],
             hue=vizdata['Store'], markers=True,
             data=vizdata, palette="tab10", linewidth=2.5)
ax.set(xlabel='Date', ylabel='Sales')
plt.show()

# %% [markdown]
# ### Aalyse Feature Importance
# Product was the most important feature.

# %%
featureimp = fit_models['rf'].best_estimator_.named_steps['randomforestregressor'].feature_importances_

# %%
imp = {}
for num, key in enumerate(X.columns[:19]):
    imp[key] = featureimp[num]

# %%
pd.DataFrame(pd.Series(imp)).sort_values(by=0, ascending=False)
# Out:
#                                          0
# Brand Affinity                4.995445e-01
# Temperature                   1.964653e-01
# RegionAffluence               1.439126e-01
# Good Weather Impact_Negative  3.483385e-02
# Time Week                     9.827965e-03
# Time Dayofyear                9.546908e-03
# Time Elapsed                  9.216887e-03
# Time Month                    8.181845e-03
# Precipitation                 5.608426e-03
# Product Size                  2.292244e-03
# Time Day                      6.065319e-04
# Time Dayofweek                2.383755e-04
# Time Is_quarter_start         1.433578e-05
# Time Is_month_end             1.237036e-05
# Time Is_month_start           8.877852e-06
# Time Is_quarter_end           3.547952e-06
# Time Is_year_end              1.079711e-06
# Time Is_year_start            3.155209e-07
# Time Year                     0.000000e+00

# %% [markdown]
# # Deployment

# %% [markdown]
# ### Save model to IBM COS

# %%
import pickle
with open('rfmodel.pkl', 'wb') as f:
    pickle.dump(model, f)

# %%
import zipfile
picklezip = zipfile.ZipFile('rfmodel.pkl.zip', 'w')
picklezip.write('rfmodel.pkl', compress_type=zipfile.ZIP_DEFLATED)
picklezip.close()

# %%
client.upload_file('rfmodel.pkl.zip', '<YOUR BUCKET>', 'rfmodel.pkl.zip')

# %% [markdown]
# ### Create Scoring Function

# %%
def score(payload):
    
    import pandas as pd
    import numpy as np
    import json

    def load_model():
        
        
        import types
        from botocore.client import Config
        import ibm_boto3

        def __iter__(self): return 0

        client = ibm_boto3.client(service_name='s3',
            ibm_api_key_id='<YOUR BUCKET>',
            ibm_auth_endpoint="https://iam.ng.bluemix.net/oidc/token",
            config=Config(signature_version='oauth'),
            endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

        obj = client.get_object(Bucket='<YOUR BUCKET>', Key='rfmodel.pkl.zip')['Body']

        # add missing __iter__ method, so pandas accepts body as file-like object
        if not hasattr(obj, "__iter__"): obj.__iter__ = types.MethodType( __iter__, obj ) 

        from io import BytesIO
        import zipfile
        import pickle

        zip_ref = zipfile.ZipFile(BytesIO(obj.read()), 'r')
        files = zip_ref.extract('rfmodel.pkl')
        
        with open('rfmodel.pkl', 'rb') as f:
            return pickle.load(f)
        
    
    model = load_model()
    
    abt = pd.get_dummies(pd.read_json(payload["values"][0]).sort_values(by=['Time Date', 'Product', 'Store']).drop(['Time Date', 'Product', 'Store', 'Value'], axis=1))
    
    return json.dumps({"predictions":list(model.predict(abt))})

# %% [markdown]
# ### Test  Scoring Function

# %%
abt = get_abt()

# %%
abt.head()
# Out:
#    Time Date  Product          Store  Value  RegionAffluence  \
# 0 2018-01-01  2511675  QLD_CW_ST0005  562.1              1.1
# 1 2018-01-01  2511675  QLD_CW_ST0203  715.4              1.4
# 2 2018-01-01  2511675  QLD_CW_ST0113  459.9              0.9
# 3 2018-01-01  2511675  QLD_CW_ST0098  408.8              0.8
# 4 2018-01-01  2511675  QLD_CW_ST0132  357.7              0.7
#
#   Good Weather Impact  Brand Affinity  Product Size  Temperature  \
# 0            Negative              10            60           27
# 1            Negative              10            60           27
# 2            Negative              10            60           27
# 3            Negative              10            60           27
# 4            Negative              10            60           27
#
#    Precipitation  ...  Time Day  Time Dayofweek  Time Dayofyear  \
# 0            0.0  ...         1               0               1
# 1            0.0  ...         1               0               1
# 2            0.0  ...         1               0               1
# 3            0.0  ...         1               0               1
# 4            0.0  ...         1               0               1
#
#    Time Is_month_end  Time Is_month_start  Time Is_quarter_end  \
# 0              False                 True                False
# 1              False                 True                False
# 2              False                 True                False
# 3              False                 True                False
# 4              False                 True                False
#
#    Time Is_quarter_start  Time Is_year_end  Time Is_year_start  Time Elapsed
# 0                   True             False                True    1514764800
# 1                   True             False                True    1514764800
# 2                   True             False                True    1514764800
# 3                   True             False                True    1514764800
# 4                   True             False                True    1514764800
#
# [5 rows x 23 columns]

# %%
X = pd.get_dummies(abt.sort_values(by=['Time Date', 'Product', 'Store']).drop(['Time Date', 'Product', 'Store', 'Value'], axis=1))

# %%
yhat_desktop = model.predict(X)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  42 out of  42 | elapsed:    3.1s finished

# %%
values = abt.to_json()
payload = {"values":[values]}

# %%
yhat_scoring = score(payload)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  42 out of  42 | elapsed:    3.1s finished

# %% [markdown]
# ### Visualise Scoring Results

# %%
res = abt.sort_values(by=['Time Date', 'Product', 'Store'])

# %%
import json
res['yhat_scoring'] = json.loads(yhat_scoring)['predictions']
res['yhat_desktop'] = yhat_desktop

# %%
res['diff'] = res['yhat_scoring'] - res['yhat_desktop']
res['diff_desk'] = res['Value'] - res['yhat_desktop']
res['diff_score'] = res['Value'] - res['yhat_scoring']

# %%
res.groupby('Time Date').sum().reset_index() \
    .sort_values(by='Time Date') \
    .plot(x='Time Date', y=['Value', 'yhat_scoring', 'yhat_desktop'], figsize=(20,5), grid=True)

# %% [markdown]
# ### Deploy to WML

# %%
from watson_machine_learning_client import WatsonMachineLearningAPIClient

# %%
creds = {
    "url": 'https://us-south.ml.cloud.ibm.com',
    "apikey": '<YOUR WATSON MACHINE LEARNING API KEY>',
    "instance_id":'<YOUR WATSON MACHINE LEARNING INSTANCE>'
}

# %%
client = WatsonMachineLearningAPIClient(creds)

# %%
function_details = client.repository.store_function(score, 'PyR')
# Out:
# No matching default runtime found. Creating one...SUCCESS
#
# Successfully created runtime with uid: e5f57887-7b13-4341-b3fa-5e549687f3b6

# %%
deployment_details = client.deployments.create(function_details['metadata']['guid'], 'PyR Scoring Deployment')
# Out:
# #######################################################################################
#
# Synchronous deployment creation for uid: '99b0baf5-19da-4111-93fd-62b092c8d2e9' started
#
# #######################################################################################
#
#
# INITIALIZING
# DEPLOY_IN_PROGRESS.
# DEPLOY_SUCCESS
#
#
# ------------------------------------------------------------------------------------------------
# Successfully finished deployment creation, deployment_uid='42b91a50-2dde-4a5d-b5a8-b65df5708b20'
# ------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Test out the Deployment

# %%
scoring_url = client.deployments.get_scoring_url(deployment_details)

# %%
payload = {'values':[abt.iloc[:100000].to_json()]}

# %%
abt.columns
# Out:
# Index(['Time Date', 'Product', 'Store', 'Value', 'RegionAffluence',
#        'Good Weather Impact', 'Brand Affinity', 'Product Size', 'Temperature',
#        'Precipitation', 'Time Year', 'Time Month', 'Time Week', 'Time Day',
#        'Time Dayofweek', 'Time Dayofyear', 'Time Is_month_end',
#        'Time Is_month_start', 'Time Is_quarter_end', 'Time Is_quarter_start',
#        'Time Is_year_end', 'Time Is_year_start', 'Time Elapsed'],
#       dtype='object')

# %%
predict = client.deployments.score(scoring_url, payload)

# %%
res = abt.iloc[:100000].sort_values(by=['Time Date', 'Product', 'Store'])

# %%
res['score'] = json.loads(predict)['predictions']

# %%
res.groupby('Time Date').sum().reset_index().sort_values(by='Time Date').plot(x='Time Date', y=['Value', 'score'], figsize=(10,5), grid=True)
